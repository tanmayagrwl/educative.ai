# %%
pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/in1'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/in1/t10k-images.idx3-ubyte
# /content/drive/MyDrive/in1/t10k-labels.idx1-ubyte
# /content/drive/MyDrive/in1/train-images.idx3-ubyte
# /content/drive/MyDrive/in1/train-labels.idx1-ubyte
# /content/drive/MyDrive/in1/t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte
# /content/drive/MyDrive/in1/t10k-images-idx3-ubyte/t10k-images-idx3-ubyte
# /content/drive/MyDrive/in1/train-labels-idx1-ubyte/train-labels-idx1-ubyte
# /content/drive/MyDrive/in1/train-images-idx3-ubyte/train-images-idx3-ubyte

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa

print ("Ai Gan")
# Out:
# Ai Gan

# %%
import numpy as np
import struct
from array import array
from os.path  import join

class MnistDataloader(object):
    def __init__(self, training_images_filepath,training_labels_filepath,
                 test_images_filepath, test_labels_filepath):
        self.training_images_filepath = training_images_filepath
        self.training_labels_filepath = training_labels_filepath
        self.test_images_filepath = test_images_filepath
        self.test_labels_filepath = test_labels_filepath

    def read_images_labels(self, images_filepath, labels_filepath):
        labels = []
        with open(labels_filepath, 'rb') as file:
            magic, size = struct.unpack(">II", file.read(8))
            if magic != 2049:
                raise ValueError('Magic number mismatch, expected 2049, got {}'.format(magic))
            labels = array("B", file.read())

        with open(images_filepath, 'rb') as file:
            magic, size, rows, cols = struct.unpack(">IIII", file.read(16))
            if magic != 2051:
                raise ValueError('Magic number mismatch, expected 2051, got {}'.format(magic))
            image_data = array("B", file.read())
        images = []
        for i in range(size):
            images.append([0] * rows * cols)
        for i in range(size):
            img = np.array(image_data[i * rows * cols:(i + 1) * rows * cols])
            img = img.reshape(28, 28)
            images[i][:] = img

        return images, labels

    def load_data(self):
        x_train, y_train = self.read_images_labels(self.training_images_filepath, self.training_labels_filepath)
        x_test, y_test = self.read_images_labels(self.test_images_filepath, self.test_labels_filepath)
        print(x_train[5])
        return (x_train, y_train),(x_test, y_test)

# %%
def change_to_right(wrong_labels):
    right_labels=[]
    for x in wrong_labels:
        for i in range(0,len(wrong_labels[0])):
            if x[i]==1:
                right_labels.append(i)
    return right_labels
num_classes = 10
input_shape = (28, 28, 1)
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = tf.convert_to_tensor(np.array(change_to_right(keras.utils.to_categorical(y_train, num_classes))))
y_test = tf.convert_to_tensor(np.array(change_to_right(keras.utils.to_categorical(y_test, num_classes))))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
image_size = 28
patch_size = 14
num_patches = (image_size // patch_size) ** 2
projection_dim = 96
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 16
mlp_head_units = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        #layers.Resizing(image_size, image_size),
        #layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)

data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    augmented = data_augmentation(inputs)
    patches = Patches(patch_size)(augmented)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    for _ in range(transformer_layers):
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        x2 = layers.Add()([attention_output, encoded_patches])
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        encoded_patches = layers.Add()([x3, x2])

    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    logits = layers.Dense(num_classes)(features)
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=0.001, weight_decay=0.0001
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/t1p/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=2000,
        epochs=100,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 27s 346ms/step - loss: 0.8489 - accuracy: 0.7262 - top-5-accuracy: 0.9505 - val_loss: 0.1716 - val_accuracy: 0.9475 - val_top-5-accuracy: 0.9977
# Epoch 2/100
# 27/27 [==============================] - 8s 280ms/step - loss: 0.2713 - accuracy: 0.9151 - top-5-accuracy: 0.9965 - val_loss: 0.0945 - val_accuracy: 0.9723 - val_top-5-accuracy: 0.9983
# Epoch 3/100
# 27/27 [==============================] - 7s 279ms/step - loss: 0.1790 - accuracy: 0.9461 - top-5-accuracy: 0.9981 - val_loss: 0.0746 - val_accuracy: 0.9793 - val_top-5-accuracy: 0.9985
# Epoch 4/100
# 27/27 [==============================] - 8s 291ms/step - loss: 0.1390 - accuracy: 0.9583 - top-5-accuracy: 0.9990 - val_loss: 0.0654 - val_accuracy: 0.9815 - val_top-5-accuracy: 0.9993
# Epoch 5/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.1100 - accuracy: 0.9662 - top-5-accuracy: 0.9993 - val_loss: 0.0555 - val_accuracy: 0.9838 - val_top-5-accuracy: 0.9995
# Epoch 6/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.1048 - accuracy: 0.9684 - top-5-accuracy: 0.9994 - val_loss: 0.0558 - val_accuracy: 0.9843 - val_top-5-accuracy: 0.9993
# Epoch 7/100
# 27/27 [==============================] - 8s 292ms/step - loss: 0.0906 - accuracy: 0.9723 - top-5-accuracy: 0.9996 - val_loss: 0.0578 - val_accuracy: 0.9850 - val_top-5-accuracy: 0.9993
# Epoch 8/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0830 - accuracy: 0.9748 - top-5-accuracy: 0.9996 - val_loss: 0.0527 - val_accuracy: 0.9848 - val_top-5-accuracy: 0.9997
# Epoch 9/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.0717 - accuracy: 0.9785 - top-5-accuracy: 0.9996 - val_loss: 0.0522 - val_accuracy: 0.9862 - val_top-5-accuracy: 0.9993
# Epoch 10/100
# 27/27 [==============================] - 7s 267ms/step - loss: 0.0703 - accuracy: 0.9780 - top-5-accuracy: 0.9997 - val_loss: 0.0542 - val_accuracy: 0.9858 - val_top-5-accuracy: 0.9995
# Epoch 11/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.0646 - accuracy: 0.9806 - top-5-accuracy: 0.9997 - val_loss: 0.0461 - val_accuracy: 0.9880 - val_top-5-accuracy: 0.9992
# Epoch 12/100
# 27/27 [==============================] - 8s 292ms/step - loss: 0.0620 - accuracy: 0.9809 - top-5-accuracy: 0.9999 - val_loss: 0.0457 - val_accuracy: 0.9887 - val_top-5-accuracy: 0.9995
# Epoch 13/100
# 27/27 [==============================] - 7s 257ms/step - loss: 0.0555 - accuracy: 0.9835 - top-5-accuracy: 0.9998 - val_loss: 0.0528 - val_accuracy: 0.9860 - val_top-5-accuracy: 0.9990
# Epoch 14/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0551 - accuracy: 0.9831 - top-5-accuracy: 0.9999 - val_loss: 0.0496 - val_accuracy: 0.9883 - val_top-5-accuracy: 0.9995
# Epoch 15/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.0536 - accuracy: 0.9833 - top-5-accuracy: 0.9998 - val_loss: 0.0395 - val_accuracy: 0.9888 - val_top-5-accuracy: 0.9995
# Epoch 16/100
# 27/27 [==============================] - 7s 257ms/step - loss: 0.0477 - accuracy: 0.9852 - top-5-accuracy: 0.9999 - val_loss: 0.0429 - val_accuracy: 0.9887 - val_top-5-accuracy: 0.9997
# Epoch 17/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0437 - accuracy: 0.9867 - top-5-accuracy: 0.9999 - val_loss: 0.0430 - val_accuracy: 0.9882 - val_top-5-accuracy: 0.9997
# Epoch 18/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0446 - accuracy: 0.9855 - top-5-accuracy: 0.9998 - val_loss: 0.0491 - val_accuracy: 0.9880 - val_top-5-accuracy: 0.9993
# Epoch 19/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.0450 - accuracy: 0.9863 - top-5-accuracy: 0.9999 - val_loss: 0.0426 - val_accuracy: 0.9893 - val_top-5-accuracy: 0.9995
# Epoch 20/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0428 - accuracy: 0.9866 - top-5-accuracy: 0.9998 - val_loss: 0.0476 - val_accuracy: 0.9890 - val_top-5-accuracy: 0.9997
# Epoch 21/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.0413 - accuracy: 0.9870 - top-5-accuracy: 0.9999 - val_loss: 0.0403 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9997
# Epoch 22/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0382 - accuracy: 0.9883 - top-5-accuracy: 0.9999 - val_loss: 0.0408 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9997
# Epoch 23/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0375 - accuracy: 0.9883 - top-5-accuracy: 0.9999 - val_loss: 0.0418 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9997
# Epoch 24/100
# 27/27 [==============================] - 7s 266ms/step - loss: 0.0368 - accuracy: 0.9885 - top-5-accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9903 - val_top-5-accuracy: 0.9997
# Epoch 25/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.0368 - accuracy: 0.9883 - top-5-accuracy: 0.9999 - val_loss: 0.0438 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9993
# Epoch 26/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0360 - accuracy: 0.9885 - top-5-accuracy: 0.9999 - val_loss: 0.0413 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9997
# Epoch 27/100
# 27/27 [==============================] - 7s 257ms/step - loss: 0.0346 - accuracy: 0.9890 - top-5-accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9995
# Epoch 28/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0356 - accuracy: 0.9891 - top-5-accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9907 - val_top-5-accuracy: 0.9995
# Epoch 29/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0336 - accuracy: 0.9895 - top-5-accuracy: 0.9999 - val_loss: 0.0440 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9995
# Epoch 30/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0310 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9883 - val_top-5-accuracy: 0.9993
# Epoch 31/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0295 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9992
# Epoch 32/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0286 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9903 - val_top-5-accuracy: 0.9997
# Epoch 33/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0315 - accuracy: 0.9904 - top-5-accuracy: 0.9999 - val_loss: 0.0468 - val_accuracy: 0.9887 - val_top-5-accuracy: 0.9992
# Epoch 34/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0314 - accuracy: 0.9904 - top-5-accuracy: 0.9999 - val_loss: 0.0496 - val_accuracy: 0.9893 - val_top-5-accuracy: 0.9995
# Epoch 35/100
# 27/27 [==============================] - 7s 264ms/step - loss: 0.0280 - accuracy: 0.9914 - top-5-accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9988
# Epoch 36/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0252 - accuracy: 0.9920 - top-5-accuracy: 1.0000 - val_loss: 0.0512 - val_accuracy: 0.9895 - val_top-5-accuracy: 0.9995
# Epoch 37/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0284 - accuracy: 0.9914 - top-5-accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9898 - val_top-5-accuracy: 0.9995
# Epoch 38/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0276 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 0.9892 - val_top-5-accuracy: 0.9993
# Epoch 39/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0251 - accuracy: 0.9920 - top-5-accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9997
# Epoch 40/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0265 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9895 - val_top-5-accuracy: 0.9992
# Epoch 41/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0293 - accuracy: 0.9905 - top-5-accuracy: 0.9999 - val_loss: 0.0482 - val_accuracy: 0.9880 - val_top-5-accuracy: 0.9997
# Epoch 42/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0252 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9883 - val_top-5-accuracy: 0.9995
# Epoch 43/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0246 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9892 - val_top-5-accuracy: 0.9995
# Epoch 44/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0251 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9907 - val_top-5-accuracy: 0.9995
# Epoch 45/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0260 - accuracy: 0.9918 - top-5-accuracy: 0.9999 - val_loss: 0.0465 - val_accuracy: 0.9893 - val_top-5-accuracy: 0.9997
# Epoch 46/100
# 27/27 [==============================] - 8s 302ms/step - loss: 0.0249 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9925 - val_top-5-accuracy: 0.9997
# Epoch 47/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0229 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9915 - val_top-5-accuracy: 0.9995
# Epoch 48/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0238 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 0.9903 - val_top-5-accuracy: 0.9997
# Epoch 49/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0252 - accuracy: 0.9922 - top-5-accuracy: 0.9999 - val_loss: 0.0427 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9997
# Epoch 50/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0231 - accuracy: 0.9929 - top-5-accuracy: 0.9999 - val_loss: 0.0496 - val_accuracy: 0.9882 - val_top-5-accuracy: 0.9993
# Epoch 51/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0274 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9992
# Epoch 52/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0232 - accuracy: 0.9931 - top-5-accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9992
# Epoch 53/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0231 - accuracy: 0.9930 - top-5-accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9995
# Epoch 54/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0225 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0511 - val_accuracy: 0.9895 - val_top-5-accuracy: 0.9993
# Epoch 55/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0237 - accuracy: 0.9923 - top-5-accuracy: 0.9999 - val_loss: 0.0474 - val_accuracy: 0.9897 - val_top-5-accuracy: 0.9993
# Epoch 56/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0204 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9997
# Epoch 57/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0189 - accuracy: 0.9939 - top-5-accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9910 - val_top-5-accuracy: 0.9995
# Epoch 58/100
# 27/27 [==============================] - 7s 259ms/step - loss: 0.0212 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9912 - val_top-5-accuracy: 0.9995
# Epoch 59/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0203 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9903 - val_top-5-accuracy: 0.9997
# Epoch 60/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0212 - accuracy: 0.9930 - top-5-accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9910 - val_top-5-accuracy: 0.9997
# Epoch 61/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0212 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9903 - val_top-5-accuracy: 0.9997
# Epoch 62/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0211 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9992
# Epoch 63/100
# 27/27 [==============================] - 7s 258ms/step - loss: 0.0207 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9997
# Epoch 64/100
# 27/27 [==============================] - 7s 264ms/step - loss: 0.0194 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9917 - val_top-5-accuracy: 0.9995
# Epoch 65/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0212 - accuracy: 0.9933 - top-5-accuracy: 0.9999 - val_loss: 0.0398 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9997
# Epoch 66/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0200 - accuracy: 0.9939 - top-5-accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9915 - val_top-5-accuracy: 0.9997
# Epoch 67/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0170 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9912 - val_top-5-accuracy: 0.9997
# Epoch 68/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0203 - accuracy: 0.9940 - top-5-accuracy: 0.9999 - val_loss: 0.0391 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9997
# Epoch 69/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0193 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9903 - val_top-5-accuracy: 0.9993
# Epoch 70/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0172 - accuracy: 0.9945 - top-5-accuracy: 0.9999 - val_loss: 0.0453 - val_accuracy: 0.9907 - val_top-5-accuracy: 0.9995
# Epoch 71/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0161 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 0.9910 - val_top-5-accuracy: 0.9995
# Epoch 72/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0180 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9872 - val_top-5-accuracy: 0.9997
# Epoch 73/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0215 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9995
# Epoch 74/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0192 - accuracy: 0.9942 - top-5-accuracy: 0.9999 - val_loss: 0.0454 - val_accuracy: 0.9907 - val_top-5-accuracy: 0.9993
# Epoch 75/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0178 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9995
# Epoch 76/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0185 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9995
# Epoch 77/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0189 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9993
# Epoch 78/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0164 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9920 - val_top-5-accuracy: 0.9992
# Epoch 79/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0199 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9888 - val_top-5-accuracy: 0.9993
# Epoch 80/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0195 - accuracy: 0.9939 - top-5-accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9907 - val_top-5-accuracy: 0.9995
# Epoch 81/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0175 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0506 - val_accuracy: 0.9897 - val_top-5-accuracy: 0.9992
# Epoch 82/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0183 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9907 - val_top-5-accuracy: 0.9997
# Epoch 83/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0173 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9908 - val_top-5-accuracy: 0.9993
# Epoch 84/100
# 27/27 [==============================] - 7s 265ms/step - loss: 0.0177 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9897 - val_top-5-accuracy: 0.9995
# Epoch 85/100
# 27/27 [==============================] - 7s 259ms/step - loss: 0.0191 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9900 - val_top-5-accuracy: 0.9993
# Epoch 86/100
# 27/27 [==============================] - 7s 265ms/step - loss: 0.0162 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9990
# Epoch 87/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0174 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9912 - val_top-5-accuracy: 0.9993
# Epoch 88/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0156 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9915 - val_top-5-accuracy: 0.9995
# Epoch 89/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0149 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9905 - val_top-5-accuracy: 0.9993
# Epoch 90/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0165 - accuracy: 0.9949 - top-5-accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9995
# Epoch 91/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0142 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 0.9912 - val_top-5-accuracy: 0.9993
# Epoch 92/100
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0165 - accuracy: 0.9949 - top-5-accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9910 - val_top-5-accuracy: 0.9995
# Epoch 93/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0162 - accuracy: 0.9949 - top-5-accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9895 - val_top-5-accuracy: 0.9983
# Epoch 94/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0150 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9913 - val_top-5-accuracy: 0.9997
# Epoch 95/100
# 27/27 [==============================] - 7s 262ms/step - loss: 0.0165 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9923 - val_top-5-accuracy: 0.9995
# Epoch 96/100
# 27/27 [==============================] - 7s 260ms/step - loss: 0.0158 - accuracy: 0.9949 - top-5-accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9897 - val_top-5-accuracy: 0.9995
# Epoch 97/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0156 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9902 - val_top-5-accuracy: 0.9993
# Epoch 98/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0153 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9913 - val_top-5-accuracy: 0.9990
# Epoch 99/100
# 27/27 [==============================] - 7s 259ms/step - loss: 0.0139 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.0505 - val_accuracy: 0.9913 - val_top-5-accuracy: 0.9995
# Epoch 100/100
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0174 - accuracy: 0.9949 - top-5-accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9912 - val_top-5-accuracy: 0.9993
# 313/313 [==============================] - 10s 24ms/step - loss: 0.0440 - accuracy: 0.9904 - top-5-accuracy: 0.9998
# Test accuracy: 99.04%
# Test top 5 accuracy: 99.98%
